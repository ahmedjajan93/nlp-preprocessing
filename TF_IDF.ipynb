# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedjajan93/nlp-preprocessing/blob/main/TF_IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TF-IDF (Term Frequency-Inverse Document Frequency) :**
#
# **TF-IDF** is a statistical measure used to evaluate how important a word is to a document in a collection or corpus.
#
# **It's widely used in :**
#
# * Information retrieval
#
# * Text mining
#
# * Search engines
#
# * Document classification

# %% [markdown]
# **How TF-IDF Works :**
#
# TF-IDF combines two metrics:
#
# * Term Frequency (TF): How often a word appears in a document
#
# * Inverse Document Frequency (IDF): How important the word is across all documents

# %% [markdown]
# **Mathematical Formulation :**
#
# **TF(t, d)** = (Number of times term t appears in document d) / (Total number of terms in document d)
#
# **IDF(t, D)** = log(Total number of documents / Number of documents containing term t)
#
# **TF-IDF(t, d, D)** = TF(t, d) * IDF(t, D)

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from datasets import load_dataset
nltk.download('stopwords')
nltk.download('wordnet')

# Example: IMDB Reviews (Sentiment Analysis)
dataset = load_dataset("imdb")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
import pandas as pd
df = pd.DataFrame(dataset['train'])

# %%
df['text'][1]
# Out:
# '"I Am Curious: Yellow" is a risible and pretentious steaming pile. It doesn\'t matter what one\'s political views are because this film can hardly be taken seriously on any level. As for the claim that frontal male nudity is an automatic NC-17, that isn\'t true. I\'ve seen R-rated films with male nudity. Granted, they only offer some fleeting views, but where are the R-rated films with gaping vulvas and flapping labia? Nowhere, because they don\'t exist. The same goes for those crappy cable shows: schlongs swinging in the breeze but not a clitoris in sight. And those pretentious indie movies like The Brown Bunny, in which we\'re treated to the site of Vincent Gallo\'s throbbing johnson, but not a trace of pink visible on Chloe Sevigny. Before crying (or implying) "double-standard" in matters of nudity, the mentally obtuse should take into account one unavoidably obvious anatomical difference between men and women: there are no genitals on display when actresses appears nude, and the same cannot be said for a man. In fact, you generally won\'t see female genitals in an American film in anything short of porn or explicit erotica. This alleged double-standard is less a double standard than an admittedly depressing ability to come to terms culturally with the insides of women\'s bodies.'

# %%
wordlemmatizer = WordNetLemmatizer()
corpus=[]
for i in range(0,len(df)):
    review=re.sub('[^a-zA-z]',' ',df['text'][i])
    review=review.lower()
    review=review.split()
    review=[wordlemmatizer.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)
    corpus.append(review)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=5000,ngram_range=(1,2))
X = tfidf.fit_transform(corpus).toarray()

# %%
import numpy as np
np.set_printoptions(edgeitems=30, linewidth=100000,
    formatter=dict(float=lambda x: "%.3g" % x))

# %%
tfidf.vocabulary_
# Out:
# {'rented': np.int64(3653),
#  'curious': np.int64(1058),
#  'yellow': np.int64(4986),
#  'video': np.int64(4768),
#  'store': np.int64(4253),
#  'surrounded': np.int64(4367),
#  'first': np.int64(1707),
#  'released': np.int64(3623),
#  'also': np.int64(143),
#  'heard': np.int64(2051),
#  'ever': np.int64(1514),
#  'tried': np.int64(4611),
#  'enter': np.int64(1468),
#  'country': np.int64(987),
#  'therefore': np.int64(4481),
#  'fan': np.int64(1622),
#  'film': np.int64(1689),
#  'considered': np.int64(920),
#  'controversial': np.int64(950),
#  'really': np.int64(3567),
#  'see': np.int64(3893),
#  'br': np.int64(507),
#  'plot': np.int64(3300),
#  'centered': np.int64(681),
#  'around': np.int64(239),
#  'young': np.int64(4992),
#  'swedish': np.int64(4384),
#  'drama': np.int64(1316),
#  'student': np.int64(4285),
#  'named': np.int64(2944),
#  'lena': np.int64(2554),
#  'want': np.int64(4824),
#  'learn': np.int64(2537),
#  'everything': np.int64(1519),
#  'life': np.int64(2576),
#  'particular': np.int64(3181),
#  'focus': np.int64(1737),
#  'attention': np.int64(289),
#  'making': np.int64(2701),
#  'sort': np.int64(4127),
#  'documentary': np.int64(1286),
#  'average': np.int64(308),
#  'thought': np.int64(4494),
#  'certain': np.int64(685),
#  'political': np.int64(3319),
#  'issue': np.int64(2347),
#  'vietnam': np.int64(4769),
#  'war': np.int64(4827),
#  'race': np.int64(3508),
#  'united': np.int64(4695),
#  'state': np.int64(4215),
#  'asking': np.int64(260),
#  'politician': np.int64(3321),
#  'ordinary': np.int64(3109),
#  'opinion': np.int64(3101),
#  'politics': np.int64(3322),
#  'sex': np.int64(3949),
#  'teacher': np.int64(4430),
#  'married': np.int64(2732),
#  'men': np.int64(2790),
#  'kill': np.int64(2450),
#  'year': np.int64(4983),
#  'ago': np.int64(96),
#  'nudity': np.int64(3047),
#  'scene': np.int64(3853),
#  'far': np.int64(1627),
#  'even': np.int64(1510),
#  'shot': np.int64(3996),
#  'like': np.int64(2583),
#  'made': np.int64(2681),
#  'porno': np.int64(3332),
#  'mind': np.int64(2835),
#  'find': np.int64(1697),
#  'shocking': np.int64(3986),
#  'reality': np.int64(3562),
#  'major': np.int64(2696),
#  'cinema': np.int64(773),
#  'bergman': np.int64(407),
#  'arguably': np.int64(232),
#  'answer': np.int64(194),
#  'good': np.int64(1917),
#  'old': np.int64(3087),
#  'boy': np.int64(504),
#  'john': np.int64(2391),
#  'ford': np.int64(1758),
#  'filmmaker': np.int64(1692),
#  'fact': np.int64(1598),
#  'shown': np.int64(4004),
#  'artistic': np.int64(251),
#  'purpose': np.int64(3483),
#  'rather': np.int64(3540),
#  'shock': np.int64(3984),
#  'people': np.int64(3216),
#  'make': np.int64(2698),
#  'money': np.int64(2877),
#  'theater': np.int64(4476),
#  'america': np.int64(160),
#  'anyone': np.int64(204),
#  'wanting': np.int64(4826),
#  'study': np.int64(4287),
#  'meat': np.int64(2774),
#  'pun': np.int64(3472),
#  'intended': np.int64(2297),
#  'much': np.int64(2915),
#  'pretentious': np.int64(3392),
#  'pile': np.int64(3267),
#  'matter': np.int64(2756),
#  'one': np.int64(3093),
#  'view': np.int64(4770),
#  'hardly': np.int64(2027),
#  'taken': np.int64(4405),
#  'seriously': np.int64(3933),
#  'level': np.int64(2569),
#  'claim': np.int64(784),
#  'male': np.int64(2702),
#  'true': np.int64(4622),
#  'seen': np.int64(3902),
#  'rated': np.int64(3539),
#  'granted': np.int64(1938),
#  'offer': np.int64(3076),
#  'nowhere': np.int64(3043),
#  'exist': np.int64(1547),
#  'go': np.int64(1905),
#  'crappy': np.int64(1005),
#  'cable': np.int64(594),
#  'show': np.int64(3998),
#  'sight': np.int64(4013),
#  'indie': np.int64(2250),
#  'movie': np.int64(2910),
#  'brown': np.int64(552),
#  'bunny': np.int64(573),
#  'treated': np.int64(4601),
#  'site': np.int64(4051),
#  'vincent': np.int64(4777),
#  'johnson': np.int64(2393),
#  'trace': np.int64(4571),
#  'pink': np.int64(3270),
#  'visible': np.int64(4785),
#  'cry': np.int64(1047),
#  'double': np.int64(1303),
#  'standard': np.int64(4201),
#  'mentally': np.int64(2795),
#  'take': np.int64(4404),
#  'account': np.int64(30),
#  'obvious': np.int64(3062),
#  'difference': np.int64(1222),
#  'woman': np.int64(4932),
#  'display': np.int64(1272),
#  'actress': np.int64(47),
#  'appears': np.int64(221),
#  'nude': np.int64(3046),
#  'cannot': np.int64(621),
#  'said': np.int64(3817),
#  'man': np.int64(2705),
#  'generally': np.int64(1861),
#  'female': np.int64(1664),
#  'american': np.int64(161),
#  'anything': np.int64(205),
#  'short': np.int64(3993),
#  'porn': np.int64(3331),
#  'explicit': np.int64(1569),
#  'less': np.int64(2562),
#  'admittedly': np.int64(67),
#  'depressing': np.int64(1168),
#  'ability': np.int64(2),
#  'come': np.int64(849),
#  'term': np.int64(4458),
#  'inside': np.int64(2277),
#  'body': np.int64(474),
#  'avoid': np.int64(309),
#  'type': np.int64(4646),
#  'future': np.int64(1831),
#  'interesting': np.int64(2306),
#  'experiment': np.int64(1561),
#  'tell': np.int64(4447),
#  'story': np.int64(4255),
#  'might': np.int64(2820),
#  'feel': np.int64(1658),
#  'sitting': np.int64(4053),
#  'thru': np.int64(4510),
#  'touch': np.int64(4560),
#  'many': np.int64(2717),
#  'important': np.int64(2220),
#  'without': np.int64(4926),
#  'viewer': np.int64(4772),
#  'away': np.int64(314),
#  'new': np.int64(2989),
#  'perspective': np.int64(3236),
#  'unless': np.int64(4700),
#  'pointless': np.int64(3310),
#  'better': np.int64(416),
#  'spend': np.int64(4157),
#  'time': np.int64(4523),
#  'staring': np.int64(4208),
#  'window': np.int64(4912),
#  'tree': np.int64(4603),
#  'growing': np.int64(1970),
#  'probably': np.int64(3418),
#  'inspired': np.int64(2281),
#  'urge': np.int64(4720),
#  'instead': np.int64(2287),
#  'two': np.int64(4644),
#  'strong': np.int64(4276),
#  'element': np.int64(1415),
#  'realistic': np.int64(3561),
#  'acting': np.int64(42),
#  'impressive': np.int64(2226),
#  'photo': np.int64(3250),
#  'apart': np.int64(209),
#  'strike': np.int64(4271),
#  'endless': np.int64(1449),
#  'silliness': np.int64(4020),
#  'annoying': np.int64(192),
#  'world': np.int64(4949),
#  'act': np.int64(40),
#  'stupid': np.int64(4294),
#  'comparing': np.int64(873),
#  'replaced': np.int64(3660),
#  'stupidity': np.int64(4295),
#  'going': np.int64(1911),
#  'subject': np.int64(4299),
#  'would': np.int64(4960),
#  'say': np.int64(3845),
#  'follows': np.int64(1745),
#  'ideal': np.int64(2188),
#  'french': np.int64(1803),
#  'society': np.int64(4102),
#  'place': np.int64(3277),
#  'oh': np.int64(3083),
#  'brother': np.int64(550),
#  'hearing': np.int64(2052),
#  'ridiculous': np.int64(3724),
#  'think': np.int64(4486),
#  'lee': np.int64(2545),
#  'song': np.int64(4121),
#  'early': np.int64(1370),
#  'teen': np.int64(4442),
#  'fish': np.int64(1709),
#  'hit': np.int64(2105),
#  'get': np.int64(1878),
#  'although': np.int64(146),
#  'manage': np.int64(2706),
#  'sneak': np.int64(4095),
#  'screening': np.int64(3871),
#  'local': np.int64(2616),
#  'museum': np.int64(2929),
#  'finally': np.int64(1695),
#  'could': np.int64(982),
#  'except': np.int64(1532),
#  'parent': np.int64(3175),
#  'reason': np.int64(3570),
#  'sand': np.int64(3826),
#  'case': np.int64(655),
#  'release': np.int64(3622),
#  'million': np.int64(2832),
#  'stinker': np.int64(4243),
#  'thinking': np.int64(4487),
#  'got': np.int64(1924),
#  'lot': np.int64(2645),
#  'street': np.int64(4264),
#  'interview': np.int64(2311),
#  'bland': np.int64(448),
#  'mall': np.int64(2703),
#  'care': np.int64(634),
#  'pale': np.int64(3161),
#  'actor': np.int64(46),
#  'cultural': np.int64(1053),
#  'icon': np.int64(2186),
#  'holy': np.int64(2120),
#  'historic': np.int64(2101),
#  'whatever': np.int64(4879),
#  'thing': np.int64(4485),
#  'burn': np.int64(575),
#  'stuff': np.int64(4288),
#  'lead': np.int64(2530),
#  'box': np.int64(501),
#  'elite': np.int64(1418),
#  'still': np.int64(4239),
#  'value': np.int64(4742),
#  'boring': np.int64(489),
#  'pseudo': np.int64(3459),
#  'revolutionary': np.int64(3709),
#  'ignored': np.int64(2196),
#  'forgotten': np.int64(1766),
#  'blank': np.int64(449),
#  'title': np.int64(4533),
#  'repeated': np.int64(3656),
#  'gay': np.int64(1854),
#  'black': np.int64(442),
#  'etc': np.int64(1501),
#  'every': np.int64(1515),
#  'ten': np.int64(4450),
#  'rise': np.int64(3733),
#  'dead': np.int64(1110),
#  'viewed': np.int64(4771),
#  'generation': np.int64(1863),
#  'naughty': np.int64(2958),
#  'industry': np.int64(2255),
#  'plague': np.int64(3279),
#  'must': np.int64(2934),
#  'rent': np.int64(3651),
#  'fast': np.int64(1638),
#  'forward': np.int64(1776),
#  'dirty': np.int64(1245),
#  'part': np.int64(3180),
#  'put': np.int64(3488),
#  'top': np.int64(4552),
#  'list': np.int64(2600),
#  'category': np.int64(665),
#  'unwatchable': np.int64(4713),
#  'trash': np.int64(4594),
#  'bad': np.int64(328),
#  'worst': np.int64(4955),
#  'kind': np.int64(2455),
#  'suppose': np.int64(4354),
#  'supposed': np.int64(4355),
#  'sequence': np.int64(3927),
#  'day': np.int64(1108),
#  'rabbit': np.int64(3507),
#  'called': np.int64(602),
#  'strictly': np.int64(4270),
#  'high': np.int64(2087),
#  'school': np.int64(3856),
#  'amateur': np.int64(151),
#  'night': np.int64(3003),
#  'self': np.int64(3906),
#  'sense': np.int64(3915),
#  'photography': np.int64(3254),
#  'harsh': np.int64(2032),
#  'white': np.int64(4887),
#  'wrong': np.int64(4974),
#  'angle': np.int64(180),
#  'sound': np.int64(4129),
#  'call': np.int64(601),
#  'art': np.int64(247),
#  'whoever': np.int64(4888),
#  'wrote': np.int64(4975),
#  'screenplay': np.int64(3872),
#  'obviously': np.int64(3063),
#  'never': np.int64(2987),
#  'book': np.int64(482),
#  'ball': np.int64(336),
#  'especially': np.int64(1493),
#  'mistake': np.int64(2859),
#  'later': np.int64(2510),
#  'write': np.int64(4969),
#  'whole': np.int64(4889),
#  'error': np.int64(1490),
#  'page': np.int64(3148),
#  'believe': np.int64(395),
#  'simply': np.int64(4031),
#  'portrayed': np.int64(3337),
#  'jr': np.int64(2405),
#  'hard': np.int64(2024),
#  'seems': np.int64(3901),
#  'awfully': np.int64(318),
#  'sloppy': np.int64(4080),
#  'saw': np.int64(3844),
#  'glimpse': np.int64(1898),
#  'quickly': np.int64(3499),
#  'noticed': np.int64(3037),
#  'playing': np.int64(3292),
#  'role': np.int64(3758),
#  'rachel': np.int64(3509),
#  'york': np.int64(4991),
#  'portrayal': np.int64(3336),
#  'lucy': np.int64(2666),
#  'absolutely': np.int64(9),
#  'awful': np.int64(317),
#  'comedian': np.int64(850),
#  'incredible': np.int64(2243),
#  'talent': np.int64(4408),
#  'legend': np.int64(2550),
#  'way': np.int64(4851),
#  'horrendous': np.int64(2143),
#  'play': np.int64(3289),
#  'producer': np.int64(3425),
#  'decided': np.int64(1127),
#  'tough': np.int64(4563),
#  'pretty': np.int64(3393),
#  'someone': np.int64(4115),
#  'resemble': np.int64(3675),
#  'least': np.int64(2541),
#  'bit': np.int64(437),
#  'similar': np.int64(4023),
#  'look': np.int64(2632),
#  'episode': np.int64(1481),
#  'love': np.int64(2652),
#  'factory': np.int64(1600),
#  'nothing': np.int64(3035),
#  'expression': np.int64(1582),
#  'voice': np.int64(4796),
#  'movement': np.int64(2909),
#  'danny': np.int64(1090),
#  'horrible': np.int64(2144),
#  'small': np.int64(4084),
#  'accent': np.int64(17),
#  'unreal': np.int64(4708),
#  'unbelievable': np.int64(4659),
#  'fred': np.int64(1797),
#  'either': np.int64(1408),
#  'character': np.int64(707),
#  'overall': np.int64(3130),
#  'extremely': np.int64(1589),
#  'casting': np.int64(659),
#  'badly': np.int64(330),
#  'told': np.int64(4539),
#  'understand': np.int64(4669),
#  'real': np.int64(3557),
#  'situation': np.int64(4054),
#  'suggest': np.int64(4325),
#  'watching': np.int64(4846),
#  'biography': np.int64(433),
#  'read': np.int64(3553),
#  'master': np.int64(2747),
#  'finding': np.int64(1698),
#  'laughter': np.int64(2519),
#  'choice': np.int64(748),
#  'compared': np.int64(872),
#  'aspect': np.int64(263),
#  'certainly': np.int64(686),
#  'audience': np.int64(295),
#  'among': np.int64(163),
#  'air': np.int64(105),
#  'production': np.int64(3428),
#  'existence': np.int64(1549),
#  'fun': np.int64(1822),
#  'shoot': np.int64(3989),
#  'nobody': np.int64(3010),
#  'getting': np.int64(1879),
#  'actual': np.int64(48),
#  'work': np.int64(4945),
#  'done': np.int64(1294),
#  'almost': np.int64(137),
#  'always': np.int64(149),
#  'watch': np.int64(4842),
#  'ritter': np.int64(3737),
#  'glass': np.int64(1896),
#  'hammer': np.int64(2004),
#  'home': np.int64(2122),
#  'status': np.int64(4220),
#  'sweet': np.int64(4385),
#  'embarrassing': np.int64(1428),
#  'guy': np.int64(1989),
#  'dating': np.int64(1100),
#  'prom': np.int64(3437),
#  'queen': np.int64(3494),
#  'ben': np.int64(404),
#  'sport': np.int64(4181),
#  'usual': np.int64(4730),
#  'cat': np.int64(661),
#  'attempt': np.int64(284),
#  'requires': np.int64(3671),
#  'hepburn': np.int64(2077),
#  'interest': np.int64(2304),
#  'couple': np.int64(990),
#  'respective': np.int64(3684),
#  'child': np.int64(741),
#  'alert': np.int64(120),
#  'daughter': np.int64(1101),
#  'cute': np.int64(1066),
#  'pick': np.int64(3259),
#  'fairly': np.int64(1608),
#  'disturbing': np.int64(1280),
#  'drawing': np.int64(1319),
#  'dignity': np.int64(1228),
#  'manages': np.int64(2709),
#  'proceeding': np.int64(3420),
#  'challenge': np.int64(692),
#  'everybody': np.int64(1516),
#  'great': np.int64(1945),
#  'expect': np.int64(1553),
#  'looking': np.int64(2634),
#  'picking': np.int64(3261),
#  'copy': np.int64(967),
#  'mentioned': np.int64(2797),
#  'camp': np.int64(609),
#  'thoroughly': np.int64(4492),
#  'singing': np.int64(4040),
#  'competent': np.int64(878),
#  'wholly': np.int64(4890),
#  'unconvincing': np.int64(4663),
#  'western': np.int64(4876),
#  'number': np.int64(3048),
#  'soundtrack': np.int64(4132),
#  'surely': np.int64(4358),
#  'stage': np.int64(4193),
#  'musical': np.int64(2931),
#  'may': np.int64(2761),
#  'slight': np.int64(4076),
#  'long': np.int64(2630),
#  'charm': np.int64(717),
#  'laughed': np.int64(2517),
#  'try': np.int64(4626),
#  'coast': np.int64(827),
#  'intention': np.int64(2301),
#  'peter': np.int64(3239),
#  'due': np.int64(1351),
#  'tragic': np.int64(4580),
#  'death': np.int64(1119),
#  'dorothy': np.int64(1301),
#  'special': np.int64(4148),
#  'heart': np.int64(2054),
#  'mr': np.int64(2912),
#  'bought': np.int64(497),
#  'back': np.int64(324),
#  'went': np.int64(4872),
#  'prove': np.int64(3451),
#  'popular': np.int64(3328),
#  'fall': np.int64(1614),
#  'sympathetic': np.int64(4393),
#  'hollywood': np.int64(2118),
#  'joy': np.int64(2404),
#  'emotional': np.int64(1434),
#  'echo': np.int64(1384),
#  'last': np.int64(2506),
#  'picture': np.int64(3262),
#  'paper': np.int64(3168),
#  'moon': np.int64(2887),
#  'doc': np.int64(1283),
#  'following': np.int64(1744),
#  'daisy': np.int64(1074),
#  'miller': np.int64(2831),
#  'though': np.int64(4493),
#  'waste': np.int64(4839),
#  'rental': np.int64(3652),
#  'park': np.int64(3177),
#  'sunny': np.int64(4340),
#  'stick': np.int64(4237),
#  'personal': np.int64(3233),
#  'based': np.int64(352),
#  'changed': np.int64(701),
#  'fit': np.int64(1713),
#  'detective': np.int64(1201),
#  'date': np.int64(1098),
#  'beautiful': np.int64(374),
#  'model': np.int64(2870),
#  'problem': np.int64(3419),
#  'millionaire': np.int64(2833),
#  'entire': np.int64(1476),
#  'written': np.int64(4973),
#  'know': np.int64(2470),
#  'indeed': np.int64(2245),
#  'leaf': np.int64(2533),
#  'bored': np.int64(487),
#  'confused': np.int64(907),
#  'jealous': np.int64(2367),
#  'murdered': np.int64(2923),
#  'right': np.int64(3728),
#  'filming': np.int64(1691),
#  'marry': np.int64(2733),
#  'keith': np.int64(2434),
#  'richards': np.int64(3717),
#  'seemed': np.int64(3899),
#  'forced': np.int64(1757),
#  'added': np.int64(55),
#  'convoluted': np.int64(961),
#  'begin': np.int64(385),
#  'somebody': np.int64(4113),
#  'relate': np.int64(3615),
#  'manhattan': np.int64(2710),
#  'rest': np.int64(3689),
#  'irritating': np.int64(2342),
#  'fest': np.int64(1667),
#  'happens': np.int64(2020),
#  'entertain': np.int64(1471),
#  'friend': np.int64(1808),
#  'joke': np.int64(2396),
#  'bore': np.int64(486),
#  'favorite': np.int64(1646),
#  'star': np.int64(4205),
#  'including': np.int64(2237),
#  'looked': np.int64(2633),
#  'quite': np.int64(3505),
#  'wonderful': np.int64(4935),
#  'given': np.int64(1892),
#  'line': np.int64(2594),
#  'neither': np.int64(2977),
#  'understood': np.int64(4673),
#  'cared': np.int64(635),
#  'smaller': np.int64(4085),
#  'fine': np.int64(1699),
#  'sidekick': np.int64(4011),
#  'showed': np.int64(4001),
#  'sad': np.int64(3810),
#  'sadly': np.int64(3812),
#  'chance': np.int64(699),
#  'open': np.int64(3096),
#  'minded': np.int64(2836),
#  'started': np.int64(4213),
#  'big': np.int64(424),
#  'enjoyed': np.int64(1460),
#  'target': np.int64(4419),
#  'surprised': np.int64(4362),
#  'barely': np.int64(345),
#  'able': np.int64(3),
#  'keep': np.int64(2432),
#  'awake': np.int64(311),
#  'ironic': np.int64(2338),
#  'agency': np.int64(92),
#  'involved': np.int64(2329),
#  'five': np.int64(1715),
#  'ex': np.int64(1525),
#  'girlfriend': np.int64(1890),
#  'television': np.int64(4446),
#  'series': np.int64(3931),
#  'stealing': np.int64(4226),
#  'idea': np.int64(2187),
#  'course': np.int64(992),
#  'ton': np.int64(4544),
#  'witty': np.int64(4929),
#  'dialogue': np.int64(1213),
#  'slapstick': np.int64(4066),
#  'bottom': np.int64(496),
#  'version': np.int64(4756),
#  'prepared': np.int64(3377),
#  'possibility': np.int64(3346),
#  'script': np.int64(3875),
#  'lack': np.int64(2488),
#  'plus': np.int64(3301),
#  'side': np.int64(4010),
#  'general': np.int64(1860),
#  'craft': np.int64(1001),
#  'technical': np.int64(4435),
#  'crew': np.int64(1027),
#  'ear': np.int64(1367),
#  'cheap': np.int64(724),
#  'laugh': np.int64(2514),
#  'seem': np.int64(3898),
#  'amazingly': np.int64(155),
#  'killing': np.int64(2453),
#  'cast': np.int64(658),
#  'bob': np.int64(472),
#  'obsessed': np.int64(3059),
#  'enough': np.int64(1465),
#  'sister': np.int64(4048),
#  'murder': np.int64(2922),
#  'hand': np.int64(2007),
#  'low': np.int64(2657),
#  'husband': np.int64(2179),
#  'silver': np.int64(4022),
#  'screen': np.int64(3870),
#  'expected': np.int64(1555),
#  'lost': np.int64(2644),
#  'masterpiece': np.int64(2749),
#  'la': np.int64(2484),
#  'orson': np.int64(3115),
#  'welles': np.int64(4870),
#  'jean': np.int64(2368),
#  'god': np.int64(1907),
#  'hair': np.int64(1994),
#  'disappointing': np.int64(1252),
#  'sit': np.int64(4049),
#  'surrounding': np.int64(4368),
#  'group': np.int64(1968),
#  'setting': np.int64(3941),
#  'director': np.int64(1241),
#  'city': np.int64(781),
#  'end': np.int64(1445),
#  'woody': np.int64(4942),
#  'allen': np.int64(130),
#  'improve': np.int64(2227),
#  'upon': np.int64(4715),
#  'none': np.int64(3018),
#  'word': np.int64(4943),
#  'unnecessary': np.int64(4704),
#  'experience': np.int64(1559),
#  'set': np.int64(3940),
#  'fantasy': np.int64(1626),
#  'hollow': np.int64(2116),
#  'shallow': np.int64(3961),
#  'message': np.int64(2805),
#  'today': np.int64(4535),
#  'found': np.int64(1780),
#  'vhs': np.int64(4760),
#  'sale': np.int64(3821),
#  'used': np.int64(4724),
#  'information': np.int64(2265),
#  'liked': np.int64(2584),
#  'reference': np.int64(3597),
#  'listed': np.int64(2601),
#  'cover': np.int64(995),
#  'name': np.int64(2943),
#  'specially': np.int64(4149),
#  'attracted': np.int64(292),
#  'price': np.int64(3399),
#  'risk': np.int64(3735),
#  'buy': np.int64(590),
#  'imdb': np.int64(2211),
#  'user': np.int64(4727),
#  'rating': np.int64(3541),
#  'excellent': np.int64(1531),
#  'martin': np.int64(2738),
#  'dvd': np.int64(1361),
#  'guide': np.int64(1982),
#  'wow': np.int64(4963),
#  'four': np.int64(1781),
#  'immediately': np.int64(2214),
#  'finished': np.int64(1703),
#  'overrated': np.int64(3136),
#  'developed': np.int64(1204),
#  'spent': np.int64(4160),
#  'minute': np.int64(2846),
#  'funny': np.int64(1827),
#  'private': np.int64(3415),
#  'eye': np.int64(1590),
#  'chasing': np.int64(721),
#  'along': np.int64(139),
#  'coincidence': np.int64(833),
#  'huge': np.int64(2162),
#  'attractive': np.int64(294),
#  'falling': np.int64(1616),
#  'brad': np.int64(508),
#  'pitt': np.int64(3275),
#  'george': np.int64(1873),
#  'greater': np.int64(1946),
#  'attraction': np.int64(293),
#  'presence': np.int64(3380),
#  'whose': np.int64(4892),
#  'amazing': np.int64(154),
#  'beauty': np.int64(376),
#  'sexy': np.int64(3953),
#  'fifty': np.int64(1678),
#  'singer': np.int64(4039),
#  'since': np.int64(4036),
#  'king': np.int64(2457),
#  'collection': np.int64(837),
#  'vote': np.int64(4801),
#  'brazil': np.int64(515),
#  'happiness': np.int64(2022),
#  'plain': np.int64(3280),
#  'delivering': np.int64(1151),
#  'reading': np.int64(3555),
#  'cue': np.int64(1051),
#  'card': np.int64(632),
#  'poor': np.int64(3324),
#  'editing': np.int64(1393),
#  'background': np.int64(326),
#  'noise': np.int64(3013),
#  'others': np.int64(3118),
#  'suck': np.int64(4314),
#  'delivers': np.int64(1152),
#  'passion': np.int64(3193),
#  'wonder': np.int64(4933),
#  'kid': np.int64(2446),
#  'definitely': np.int64(1141),
#  'another': np.int64(193),
#  'project': np.int64(3436),
#  'please': np.int64(3295),
#  'suggests': np.int64(4328),
#  'friendship': np.int64(1810),
#  'piece': np.int64(3264),
#  'garbage': np.int64(1845),
#  'sum': np.int64(4334),
#  'caused': np.int64(671),
#  'purchase': np.int64(3478),
#  'subplots': np.int64(4302),
#  'stiff': np.int64(4238),
#  'confusing': np.int64(908),
#  'believable': np.int64(394),
#  'disappointed': np.int64(1251),
#  'best': np.int64(412),
#  'pathetic': np.int64(3198),
#  'library': np.int64(2574),
#  'disbelief': np.int64(1255),
#  'totally': np.int64(4559),
#  'robin': np.int64(3748),
#  'feature': np.int64(1653),
#  'appearance': np.int64(218),
#  'prior': np.int64(3412),
#  'little': np.int64(2608),
#  'bow': np.int64(500),
#  'nod': np.int64(3011),
#  'comedy': np.int64(852),
#  'shadow': np.int64(3956),
#  'twenty': np.int64(4638),
#  'earlier': np.int64(1369),
#  'sinatra': np.int64(4035),
#  'loud': np.int64(2647),
#  'sure': np.int64(4357),
#  'wait': np.int64(4806),
#  'credit': np.int64(1023),
#  'something': np.int64(4116),
#  'mean': np.int64(2767),
#  'well': np.int64(4869),
#  'guess': np.int64(1978),
#  'european': np.int64(1507),
#  'lady': np.int64(2493),
#  'occasionally': np.int64(3066),
#  'grow': np.int64(1969),
#  'period': np.int64(3229),
#  'ann': np.int64(187),
#  'played': np.int64(3290),
#  'unbelievably': np.int64(4660),
#  'material': np.int64(2753),
#  'person': np.int64(3231),
#  'charming': np.int64(718),
#  'dreadful': np.int64(1321),
#  'performance': np.int64(3223),
#  'atrocious': np.int64(279),
#  'tv': np.int64(4636),
#  'robert': np.int64(3747),
#  'wagner': np.int64(4805),
#  'thief': np.int64(4483),
#  'intelligent': np.int64(2296),
#  'turner': np.int64(4634),
#  'effective': np.int64(1401),
#  'took': np.int64(4549),
#  'bothered': np.int64(494),
#  'clothes': np.int64(818),
#  'tacky': np.int64(4400),
#  'road': np.int64(3742),
#  'perhaps': np.int64(3228),
#  'perfect': np.int64(3219),
#  'possibly': np.int64(3348),
#  'girl': np.int64(1889),
#  'recommend': np.int64(3583),
#  'truly': np.int64(4623),
#  'otherwise': np.int64(3119),
#  'critic': np.int64(1033),
#  'david': np.int64(1103),
#  'phrase': np.int64(3255),
#  'losing': np.int64(2642),
#  'appeal': np.int64(215),
#  'ask': np.int64(258),
#  'sandra': np.int64(3828),
#  'dee': np.int64(1131),
#  'pitiful': np.int64(3274),
#  'budget': np.int64(561),
#  'spoke': np.int64(4177),
#  'sounded': np.int64(4130),
#  'silly': np.int64(4021),
#  'garden': np.int64(1847),
#  'somewhat': np.int64(4118),
#  'walk': np.int64(4811),
#  'english': np.int64(1457),
#  'wax': np.int64(4850),
#  'flower': np.int64(1733),
#  'nature': np.int64(2957),
#  'fictional': np.int64(1674),
#  'profound': np.int64(3433),
#  'light': np.int64(2580),
#  'poetic': np.int64(3305),
#  'fair': np.int64(1607),
#  'garbo': np.int64(1846),
#  'several': np.int64(3946),
#  'final': np.int64(1693),
#  'brief': np.int64(529),
#  'angel': np.int64(176),
#  'spielberg': np.int64(4162),
#  'corny': np.int64(970),
#  'service': np.int64(3937),
#  'church': np.int64(769),
#  'included': np.int64(2235),
#  'simple': np.int64(4028),
#  'gift': np.int64(1883),
#  'program': np.int64(3434),
#  'sudden': np.int64(4316),
#  'river': np.int64(3740),
#  'fire': np.int64(1704),
#  'escape': np.int64(1491),
#  'brought': np.int64(551),
#  'emotion': np.int64(1433),
#  'tear': np.int64(4433),
#  'nun': np.int64(3050),
#  'greatest': np.int64(1947),
#  'became': np.int64(377),
#  'common': np.int64(866),
#  'human': np.int64(2166),
#  'nevertheless': np.int64(2988),
#  'flaw': np.int64(1722),
#  'pointed': np.int64(3309),
#  'late': np.int64(2508),
#  'contained': np.int64(932),
#  'talk': np.int64(4410),
#  'original': np.int64(3111),
#  'dark': np.int64(1093),
#  'starred': np.int64(4210),
#  'broadway': np.int64(543),
#  'completely': np.int64(884),
#  'adequate': np.int64(63),
#  'downhill': np.int64(1307),
#  'next': np.int64(2995),
#  'weekend': np.int64(4865),
#  'working': np.int64(4948),
#  'hope': np.int64(2135),
#  'maker': np.int64(2699),
#  'crap': np.int64(1004),
#  'job': np.int64(2387),
#  'sucked': np.int64(4315),
#  'total': np.int64(4558),
#  'let': np.int64(2566),
#  'pro': np.int64(3417),
#  'con': np.int64(893),
#  'summary': np.int64(4335),
#  'reporter': np.int64(3663),
#  'run': np.int64(3796),
#  'killed': np.int64(2451),
#  'zombie': np.int64(4998),
#  'review': np.int64(3706),
#  'across': np.int64(39),
#  'chronicle': np.int64(766),
#  'filmed': np.int64(1690),
#  'buck': np.int64(558),
#  'horror': np.int64(2149),
#  'relies': np.int64(3626),
#  'lame': np.int64(2496),
#  'save': np.int64(3841),
#  'gore': np.int64(1921),
#  'gross': np.int64(1965),
#  'frightening': np.int64(1812),
#  'sexually': np.int64(3952),
#  'disease': np.int64(1264),
#  'cent': np.int64(679),
#  'company': np.int64(870),
#  'brain': np.int64(510),
#  'damage': np.int64(1076),
#  'negative': np.int64(2973),
#  'behind': np.int64(390),
#  'advice': np.int64(77),
#  'twist': np.int64(4642),
#  'ending': np.int64(1448),
#  'close': np.int64(811),
#  'ups': np.int64(4717),
#  'opening': np.int64(3098),
#  'tends': np.int64(4455),
#  'spoil': np.int64(4174),
#  'produced': np.int64(3424),
#  'worked': np.int64(4946),
#  'miracle': np.int64(2847),
#  'hire': np.int64(2099),
#  'actually': np.int64(49),
#  'gesture': np.int64(1877),
#  'joe': np.int64(2388),
#  'past': np.int64(3195),
#  'prop': np.int64(3442),
#  'costume': np.int64(980),
#  'surprise': np.int64(4361),
#  'reveal': np.int64(3700),
#  'soon': np.int64(4122),
#  'introduce': np.int64(2316),
#  'kudos': np.int64(2478),
#  'trying': np.int64(4627),
#  'honesty': np.int64(2128),
#  'st': np.int64(4189),
#  'watched': np.int64(4844),
#  'mindless': np.int64(2837),
#  'flesh': np.int64(1725),
#  'eating': np.int64(1382),
#  'within': np.int64(4925),
#  'yes': np.int64(4987),
#  'usually': np.int64(4731),
#  'underlying': np.int64(4666),
#  'classic': np.int64(792),
#  'thrown': np.int64(4509),
#  'extra': np.int64(1586),
#  'throughout': np.int64(4506),
#  'twilight': np.int64(4640),
#  'zone': np.int64(4999),
#  'easily': np.int64(1375),
#  'slow': np.int64(4081),
#  'revealed': np.int64(3701),
#  'finale': np.int64(1694),
#  'ghost': np.int64(1880),
#  'town': np.int64(4569),
#  'flick': np.int64(1726),
#  'ala': np.int64(112),
#  'free': np.int64(1799),
#  'hell': np.int64(2069),
#  'main': np.int64(2692),
#  'driving': np.int64(1335),
#  'hello': np.int64(2070),
#  'continuity': np.int64(942),
#  'hideous': np.int64(2085),
#  'effect': np.int64(1400),
#  'vision': np.int64(4786),
#  'hunting': np.int64(2177),
#  'season': np.int64(3883),
#  'blood': np.int64(461),
#  'age': np.int64(90),
#  'en': np.int64(1442),
#  'route': np.int64(3783),
#  'lay': np.int64(2526),
#  'beaten': np.int64(370),
#  'track': np.int64(4572),
#  'strange': np.int64(4260),
#  'agrees': np.int64(99),
#  'help': np.int64(2071),
#  'direct': np.int64(1236),
#  'pair': np.int64(3157),
#  'gruesome': np.int64(1974),
#  'tale': np.int64(4407),
#  'connected': np.int64(911),
#  'area': np.int64(231),
#  'eventually': np.int64(1513),
#  'suffer': np.int64(4319),
#  'worse': np.int64(4954),
#  'fate': np.int64(1642),
#  'attacked': np.int64(283),
#  'second': np.int64(3885),
#  ...}
